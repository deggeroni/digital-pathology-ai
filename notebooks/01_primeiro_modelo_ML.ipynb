# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
dados = pd.DataFrame({
    "tamanho_tumor": [5, 6, 7, 20, 22, 25],
    "idade": [25, 30, 35, 60, 65, 70],
    "diagnostico": [0, 0, 0, 1, 1, 1]
})

dados
# Out:
#    tamanho_tumor  idade  diagnostico
# 0              5     25            0
# 1              6     30            0
# 2              7     35            0
# 3             20     60            1
# 4             22     65            1
# 5             25     70            1

# %%
X = dados[["tamanho_tumor", "idade"]]

y = dados["diagnostico"]

# %%
# Separando dados de treino e teste

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

# %%
# Criando o modelo

modelo = LogisticRegression()

# %%
# Aprendizado

modelo.fit(X_train, y_train)

# %%
print("Treino:")
print(X_train)

print("\nTeste:")
print(X_test)
