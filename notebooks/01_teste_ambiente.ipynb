# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

print("Ambiente OncoAI funcionando!")
print("NumPy:", np.__version__)
print("Pandas:", pd.__version__)
print("Scikit-learn:", sklearn.__version__)
# Out:
# Ambiente OncoAI funcionando!
# NumPy: 2.2.6
# Pandas: 2.3.3
# Scikit-learn: 1.7.2
